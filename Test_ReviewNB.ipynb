# %% [markdown]
# # Test notebook for ReviewNB

# %%
import numpy as np
import xarray as xr
import pandas as pd

# %%
data = np.random.rand(4, 3)
locs = ["IA", "IL", "IN"]
times = pd.date_range("2000-01-01", periods=4)
foo = xr.DataArray(data, coords=[times, locs], dims=["time", "space"])

foo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_m/b05glfgs2sz3rs2q6cnl577r0000gn/T/ipykernel_10070/1510950722.py in <module>
#       1 data = np.random.rand(4, 3)
#       2 locs = ["IA", "IL", "IN"]
# ----> 3 times = pd.date_range("2000-01-01", periods=4)
#       4 foo = xr.DataArray(data, coords=[times, locs], dims=["time", "space"])
#       5
#
# NameError: name 'pd' is not defined
